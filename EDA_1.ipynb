# %% [markdown]
# # 1. Import required libraries and load penguins dataset from seaborn

# %%
import pandas as pd

# %% [markdown]
# # 2. Perform the following operations on the penguins dataset
#
#
# ---
#
#
#
# 1. Print first 25 entries
# 2. Print last 10 entries
# 3. Print number of rows and columns in the dataset
# 4. Print names of all the columns
# 5. What is the data type of each column
# 6. Print only species column
# 7. How many different types of species are their in this dataset
# 8. What is the most popular species
# 9. Summarize the DataFrame
# 10. Summarize all the columns
# 11. Summarize only bill_length_mm column
# 12. what is the mean of body_mass_g
# 13. How many different islands are there in this dataset and print their names
# 14. Find total count of occurenace of each gender
# 15. Print rows 3-9
# 16. Select every row after the fourth row and all columns
# 17. Select every row upto 4th row and all columns
# 18. Select rows where bill_length_mm is greater than 39
# 19. Select the rows with index 3 & 5
# 18. For each island, calculate minimum and maximum flipper_length_mm
# 19. Find the average flipper_length_mm for each gender
# 20. Plot line graph between flipper_length_mm vs bill_depth_mm
# 21. Plot scatter plot between flipper_length_mm vs bill_depth_mm with gender as hue.

# %%
import seaborn as sns
df = sns.load_dataset("penguins")
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
#1. Print first 25 entries
df.head(25)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
# 15  Adelie  Torgersen            36.6           17.8              185.0
# 16  Adelie  Torgersen            38.7           19.0              195.0
# 17  Adelie  Torgersen            42.5           20.7              197.0
# 18  Adelie  Torgersen            34.4           18.4              184.0
# 19  Adelie  Torgersen            46.0           21.5              194.0
# 20  Adelie     Biscoe            37.8           18.3              174.0
# 21  Adelie     Biscoe            37.7           18.7              180.0
# 22  Adelie     Biscoe            35.9           19.2              189.0
# 23  Adelie     Biscoe            38.2           18.1              185.0
# 24  Adelie     Biscoe            38.8           17.2              180.0
#
#     body_mass_g     sex
# 0        3750.0    Male
# 1        3800.0  Female
# 2        3250.0  Female
# 3           NaN     NaN
# 4        3450.0  Female
# 5        3650.0    Male
# 6        3625.0  Female
# 7        4675.0    Male
# 8        3475.0     NaN
# 9        4250.0     NaN
# 10       3300.0     NaN
# 11       3700.0     NaN
# 12       3200.0  Female
# 13       3800.0    Male
# 14       4400.0    Male
# 15       3700.0  Female
# 16       3450.0  Female
# 17       4500.0    Male
# 18       3325.0  Female
# 19       4200.0    Male
# 20       3400.0  Female
# 21       3600.0    Male
# 22       3800.0  Female
# 23       3950.0    Male
# 24       3800.0    Male

# %%
#2. Print last 10 entries
df.tail(10)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 334  Gentoo  Biscoe            46.2           14.1              217.0
# 335  Gentoo  Biscoe            55.1           16.0              230.0
# 336  Gentoo  Biscoe            44.5           15.7              217.0
# 337  Gentoo  Biscoe            48.8           16.2              222.0
# 338  Gentoo  Biscoe            47.2           13.7              214.0
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 334       4375.0  Female
# 335       5850.0    Male
# 336       4875.0     NaN
# 337       6000.0    Male
# 338       4925.0  Female
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male

# %%
#3. Print number of rows and columns in the dataset
df.shape
# Out:
# (344, 7)

# %%
#4. Print names of all the columns

df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
#5. What is the data type of each column

df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
#7. How many different types of species are their in this dataset

df['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
# 8. What is the most popular species

df['species'].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
# 9. Summarize the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
#10. Summarize all the columns
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
#11. Summarize only bill_length_mm column
df['bill_length_mm'].describe()
# Out:
# count    342.000000
# mean      43.921930
# std        5.459584
# min       32.100000
# 25%       39.225000
# 50%       44.450000
# 75%       48.500000
# max       59.600000
# Name: bill_length_mm, dtype: float64

# %%
#12. what is the mean of body_mass_g 

df['body_mass_g'].mean()
# Out:
# 4201.754385964912

# %%
#13. How many different islands are there in this dataset and print their names

df['island'].unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
#14. Find total count of occurenace of each gender
df['sex'].value_counts()
# Out:
# Male      168
# Female    165
# Name: sex, dtype: int64

# %%
#15. Print rows 3-9

df[3:10]
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex
# 3          NaN     NaN
# 4       3450.0  Female
# 5       3650.0    Male
# 6       3625.0  Female
# 7       4675.0    Male
# 8       3475.0     NaN
# 9       4250.0     NaN

# %%
#16. Select every row after the fourth row and all columns

df[4::]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 8    Adelie  Torgersen            34.1           18.1              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 4         3450.0  Female
# 5         3650.0    Male
# 6         3625.0  Female
# 7         4675.0    Male
# 8         3475.0     NaN
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [340 rows x 7 columns]

# %%
#18. Select rows where bill_length_mm is greater than 39
df[df['bill_length_mm']>39]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 5         3650.0    Male
# 7         4675.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [260 rows x 7 columns]

# %%
#19. Select the rows with index 3 & 5
df.iloc[[3,5]]
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g   sex
# 3          NaN   NaN
# 5       3650.0  Male

# %%
#18. For each island, calculate minimum and maximum flipper_length_mm
df.groupby('island')['flipper_length_mm'].agg(['min','max'])
# Out:
#              min    max
# island
# Biscoe     172.0  231.0
# Dream      178.0  212.0
# Torgersen  176.0  210.0

# %%
#19. Find the average flipper_length_mm for each gender

df.groupby('sex')['flipper_length_mm'].mean()
# Out:
# sex
# Female    197.363636
# Male      204.505952
# Name: flipper_length_mm, dtype: float64

# %%
# 20. Plot line graph between flipper_length_mm vs bill_depth_mm
import seaborn as sns

sns.lineplot(x=df['flipper_length_mm'],y=df['bill_depth_mm'])

# %%
#21. Plot scatter plot between flipper_length_mm vs bill_depth_mm with gender as hue.

sns.scatterplot(x=df['flipper_length_mm'],y=df['bill_depth_mm'],hue=df['sex'])

# %%
raw_data_1 = {
        'subject_id': ['1', '2', '3', '4', '5'],
        'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'], 
        'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}

raw_data_2 = {
        'subject_id': ['4', '5', '6', '7', '8'],
        'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'], 
        'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}

raw_data_3 = {
        'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
        'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %% [markdown]
# # 3. Create the 3 DataFrames based on the following raw data and assign to data1, data2, data3

# %%
raw_data_1 = pd.DataFrame(raw_data_1)
raw_data_2 = pd.DataFrame(raw_data_2)
raw_data_3 = pd.DataFrame(raw_data_3)

# %% [markdown]
# # 3. Join the first two dataframes along rows and assign all_data

# %%
all_data=raw_data_1.append(raw_data_2)
all_data
# Out:
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %% [markdown]
# # 4. Merge all_data and data3 along the subject_id value

# %%
df2=pd.merge(all_data,raw_data_3,on=['subject_id','subject_id'])
df2
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15
